# %% [markdown]
# MPI(Message Passing Interface)
#
# [环境搭建](http://zhbzz2007.github.io/Dev-Environment/MPI-Python.html):
#
# - windows: 先安装[microsoft MPI](https://www.microsoft.com/en-us/download/details.aspx?id=56727), 然后`conda install mpi4py`
# - Linux, etc: 先安装[Open MPI](https://www.open-mpi.org/), 然后`conda install mpi4py`
#
# command-line执行py:
#
# - windows: `mpiexec -n 5 python test.py`
# - Linux, etc: `mpirun -np 5 python test.py`

# %% [markdown]
# ### Test mpi4py installation

# %%
from mpi4py import MPI

# %%
dir(MPI)
# Out:
# ['AINT',
#  'ANY_SOURCE',
#  'ANY_TAG',
#  'APPNUM',
#  'Add_error_class',
#  'Add_error_code',
#  'Add_error_string',
#  'Alloc_mem',
#  'Attach_buffer',
#  'BAND',
#  'BOOL',
#  'BOR',
#  'BOTTOM',
#  'BSEND_OVERHEAD',
#  'BXOR',
#  'BYTE',
#  'CART',
#  'CHAR',
#  'CHARACTER',
#  'COMBINER_CONTIGUOUS',
#  'COMBINER_DARRAY',
#  'COMBINER_DUP',
#  'COMBINER_F90_COMPLEX',
#  'COMBINER_F90_INTEGER',
#  'COMBINER_F90_REAL',
#  'COMBINER_HINDEXED',
#  'COMBINER_HINDEXED_BLOCK',
#  'COMBINER_HVECTOR',
#  'COMBINER_INDEXED',
#  'COMBINER_INDEXED_BLOCK',
#  'COMBINER_NAMED',
#  'COMBINER_RESIZED',
#  'COMBINER_STRUCT',
#  'COMBINER_SUBARRAY',
#  'COMBINER_VECTOR',
#  'COMM_NULL',
#  'COMM_SELF',
#  'COMM_TYPE_SHARED',
#  'COMM_WORLD',
#  'COMPLEX',
#  'COMPLEX16',
#  'COMPLEX32',
#  'COMPLEX4',
#  'COMPLEX8',
#  'CONGRUENT',
#  'COUNT',
#  'CXX_BOOL',
#  'CXX_DOUBLE_COMPLEX',
#  'CXX_FLOAT_COMPLEX',
#  'CXX_LONG_DOUBLE_COMPLEX',
#  'C_BOOL',
#  'C_COMPLEX',
#  'C_DOUBLE_COMPLEX',
# ...

# %% [markdown]
# ### run mpi
#
# [using mpi](https://ipyparallel.readthedocs.io/en/latest/mpi.html):
#
# - `ipcluster start -n 4 --engines=MPIEngineSetLauncher`
# - `ipcluster start --profile=mpi -n 4`
#
# 然后直接在IPython, Jupyter中使用了, 上面链接的例子
